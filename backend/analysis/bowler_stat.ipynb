# %%
import pandas as pd

# %%
df = pd.read_csv("../output/ipl-delivery-clean.csv")
df.sample(5)
# Out:
#         Unnamed: 0  match_id  inning         batting_team  \
# 108315      108315       457       2  Chennai Super Kings
# 30856        30856       133       1     Delhi Daredevils
# 110206      110206       465       1  Chennai Super Kings
# 130599      130599       551       2  Chennai Super Kings
# 104966      104966       443       1     Delhi Daredevils
#
#                bowling_team  over  ball       batsman non_striker  \
# 108315       Mumbai Indians     5     5      DJ Bravo     M Vijay
# 30856      Rajasthan Royals    18     3      M Manhas  DL Vettori
# 110206     Delhi Daredevils    19     2     RA Jadeja    MS Dhoni
# 130599  Sunrisers Hyderabad     8     2  F du Plessis    SK Raina
# 104966      Kings XI Punjab    10     2     DA Warner   MC Juneja
#
#               bowler  ...  bye_runs  legbye_runs  noball_runs  penalty_runs  \
# 108315       PP Ojha  ...         0            0            0             0
# ...

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df
# Out:
#         match_id  inning         batting_team                 bowling_team  \
# 0              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 1              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 2              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 3              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# 4              1       1  Sunrisers Hyderabad  Royal Challengers Bangalore
# ...          ...     ...                  ...                          ...
# 179073     11415       2  Chennai Super Kings               Mumbai Indians
# 179074     11415       2  Chennai Super Kings               Mumbai Indians
# 179075     11415       2  Chennai Super Kings               Mumbai Indians
# 179076     11415       2  Chennai Super Kings               Mumbai Indians
# 179077     11415       2  Chennai Super Kings               Mumbai Indians
#
# ...

# %% [markdown]
# ## Group by bowler name

# %%
bowlers_group = df.groupby("bowler")

# %%
ts_mills_group = bowlers_group.get_group("TS Mills")

# %%
ts_mills_bowled_against = ts_mills_group["batting_team"].unique().tolist()

# %%
ts_mills_bowled_against
# Out:
# ['Sunrisers Hyderabad',
#  'Delhi Daredevils',
#  'Kings XI Punjab',
#  'Mumbai Indians',
#  'Kolkata Knight Riders']

# %%
def get_ts_mills_bowling_stats():
    g = ts_mills_group.groupby(["batting_team", "match_id", "over"])
    for team in ts_mills_bowled_against:
        print(g.get_group(team))


get_ts_mills_bowling_stats()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 7
#       3     for team in ts_mills_bowled_against:
#       4         print(g.get_group(team))
# ----> 7 get_ts_mills_bowling_stats()
#
# Cell In[23], line 4, in get_ts_mills_bowling_stats()
#       2 g = ts_mills_group.groupby(["batting_team", "match_id", "over"])
#       3 for team in ts_mills_bowled_against:
# ----> 4     print(g.get_group(team))
#
# File D:\Machine Learning\ipl-delivery-analysis\backend\env\Lib\site-packages\pandas\core\groupby\groupby.py:1113, in BaseGroupBy.get_group(self, name, obj)
#    1103     elif not isinstance(name, tuple):
#    1104         warnings.warn(
#    1105             "When grouping with a length-1 list-like, "
#    1106             "you will need to pass a length-1 tuple to get_group in a future "
#    (...)   1110             stacklevel=find_stack_level(),
# ...
